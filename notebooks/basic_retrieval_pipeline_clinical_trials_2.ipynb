# %% [markdown]
# # Downloading, Unzipping, extracting trial's parts, create final dataframe. [No need to run]

# %% [markdown]
# ## Libraries and Data Downloading

# %%
# import os
# import glob
# import pickle
# import pandas as pd

# !wget https://www.trec-cds.org/2021_data/ClinicalTrials.2021-04-27.part1.zip
# !wget https://www.trec-cds.org/2021_data/ClinicalTrials.2021-04-27.part2.zip
# !wget https://www.trec-cds.org/2021_data/ClinicalTrials.2021-04-27.part3.zip
# !wget https://www.trec-cds.org/2021_data/ClinicalTrials.2021-04-27.part4.zip
# !wget https://www.trec-cds.org/2021_data/ClinicalTrials.2021-04-27.part5.zip

# %% [markdown]
# ## Unzipping

# %%
# zip_files = ['path to each zip','']
# extracted_folder = 'path to folder to extract'

# for zip_file_path in zip_files:
#     # Unzip the file into the specified extracted folder
#     with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#         zip_ref.extractall(extracted_folder)

#     # Print the contents of the extracted folder after each zip is processed
#     print(f"Contents of {zip_file_path} extracted to: {extracted_folder}")

# print("Unzipping completed successfully.")

# %% [markdown]
# ## Util Functions to extract document parts

# %%
## Util functions to extract criteria
def get_element_text(element):
    return element.text.strip() if element is not None and element.text is not None else ''
import re

## Extraction of inclusion and exclusion criteria
def extract_criteria(criteria_text):
    inclusion_criteria = re.findall(r'Inclusion Criteria|Inclusion criteria|INCLUSION CRITERIA|Main inclusion criteria include', criteria_text)
    exclusion_criteria = re.findall(r'Exclusion Criteria|EXCLUSION CRITERIA|Exclusion criteria|Main exclusion criteria include', criteria_text)

    # Different cases that the inclusion/exclusion criteria can be found
    if inclusion_criteria and exclusion_criteria:
        # Case 1: Both Inclusion and Exclusion Criteria are present
        inclusion_index = criteria_text.find(inclusion_criteria[0])
        exclusion_index = criteria_text.find(exclusion_criteria[0])
        eligibility_data = {
            'eligibility_inclusion_criteria': criteria_text[inclusion_index+len(inclusion_criteria[0]):exclusion_index].strip(),
            'eligibility_exclusion_criteria': criteria_text[exclusion_index+len(exclusion_criteria[0]):].strip(),
        }
    elif inclusion_criteria:
        # Case 3: Only Inclusion Criteria is present
        inclusion_index = criteria_text.find(inclusion_criteria[0])
        eligibility_data = {
            'eligibility_inclusion_criteria': criteria_text[inclusion_index+len(inclusion_criteria[0]):].strip(),
            'eligibility_exclusion_criteria': '',
        }
    elif exclusion_criteria:
        # Case 4: Only Exclusion Criteria is present
        exclusion_index = criteria_text.find(exclusion_criteria[0])
        eligibility_data = {
            'eligibility_inclusion_criteria': criteria_text[:exclusion_index].strip(),
            'eligibility_exclusion_criteria': criteria_text[exclusion_index+len(exclusion_criteria[0]):].strip(),
        }
    else:
        # Case 5: Neither Inclusion nor Exclusion Criteria are present
        inclusion = re.findall(r'Inclusion|INCLUSION', criteria_text)
        exclusion = re.findall(r'Exclusion|EXCLUSION', criteria_text)

        if inclusion and exclusion:
          # Case 6: Both Inclusion and Exclusion are present
          inclusion_index = criteria_text.find(inclusion[0])
          exclusion_index = criteria_text.find(exclusion[0])
          eligibility_data = {
              'eligibility_inclusion_criteria': criteria_text[inclusion_index+len(inclusion[0]):exclusion_index].strip(),
              'eligibility_exclusion_criteria': criteria_text[exclusion_index+len(exclusion[0]):].strip(),
           }
        elif inclusion:
          # Case 7: Only Inclusion Criteria is present
          inclusion_index = criteria_text.find(inclusion[0])
          eligibility_data = {
              'eligibility_inclusion_criteria': criteria_text[inclusion_index+len(inclusion[0]):].strip(),
              'eligibility_exclusion_criteria': '',
          }
        elif exclusion:
          # Case 8: Only Exclusion Criteria is present
          exclusion_index = criteria_text.find(exclusion[0])
          eligibility_data = {
              'eligibility_inclusion_criteria': criteria_text[:exclusion_index].strip(),
              'eligibility_exclusion_criteria': criteria_text[exclusion_index+len(exclusion[0]):].strip(),
          }
        else:
          # Case 9: Neither Inclusion nor Exclusion solely or with Criteria are present
          eligibility_data = {
              'eligibility_inclusion_criteria': criteria_text,
              'eligibility_exclusion_criteria': criteria_text,
          }

    return eligibility_data

# Extract other tags of the eligibilty section
def extract_eligibility(eligibility_element):
    eligibility_data = {
        'eligibility_criteria': '',
        'eligibility_inclusion_criteria': '',
        'eligibility_exclusion_criteria': '',
        'eligibility_gender': '',
        'eligibility_minimum_age': '',
        'eligibility_maximum_age': '',
        'eligibility_healthy_volunteers': ''
    }

    if eligibility_element is not None:
        criteria_element = eligibility_element.find('criteria/textblock')
        if criteria_element is not None:
            criteria_text = criteria_element.text.strip()
            if criteria_text:
                eligibility_data['eligibility_criteria'] = criteria_text

                # Extract inclusion and exclusion criteria
                criteria_data = extract_criteria(criteria_text)
                eligibility_data.update(criteria_data)

        gender_element = eligibility_element.find('gender')
        eligibility_data['eligibility_gender'] = gender_element.text.strip() if gender_element is not None else ''

        min_age_element = eligibility_element.find('minimum_age')
        eligibility_data['eligibility_minimum_age'] = min_age_element.text.strip() if min_age_element is not None else ''

        max_age_element = eligibility_element.find('maximum_age')
        eligibility_data['eligibility_maximum_age'] = max_age_element.text.strip() if max_age_element is not None else ''

        volunteers_element = eligibility_element.find('healthy_volunteers')
        eligibility_data['eligibility_healthy_volunteers'] = volunteers_element.text.strip() if volunteers_element is not None else ''

    return eligibility_data

# Given a clinical trial in .xml format, extract several of its fields
def extract_tags(xml_data):
    root = ET.fromstring(xml_data)

    data_dict = {
        #id_info_nct_id
        'nct_id': get_element_text(root.find('.//id_info/nct_id')),
        'brief_title': get_element_text(root.find('brief_title')),
        'official_title': get_element_text(root.find('official_title')),
        'brief_summary': get_element_text(root.find('.//brief_summary/textblock')),
        'detailed_description': get_element_text(root.find('.//detailed_description/textblock')),
        'study_type': get_element_text(root.find('study_type')),
        'study_design_info_primary_purpose': get_element_text(root.find('.//study_design_info/primary_purpose')),
        'condition': get_element_text(root.find('condition')),
        'intervention_intervention_type': get_element_text(root.find('.//intervention/intervention_type')),
        'intervention_intervention_name': get_element_text(root.find('.//intervention/intervention_name')),
        'location': get_element_text(root.find('.//location/facility/name')),
        'trials_keyword': ', '.join([get_element_text(elem) for elem in root.findall('.//keyword')]),
        'condition_browse_mesh_term': get_element_text(root.find('.//condition_browse/mesh_term')),
        'intervention_browse_mesh_term': ', '.join([get_element_text(elem) for elem in root.findall('.//intervention_browse/mesh_term')])
    }

    # Extract eligibility section
    eligibility_element = root.find('eligibility')
    data_dict.update(extract_eligibility(eligibility_element))

    return data_dict

# %% [markdown]
# ## Extract Information from the .xml files

# %%
# Initialize the list to store all the extracted documents
# all_documents = []

# Define the chunk size to save data in chunks
# chunk_size = 10000

# path_to_save_data = ''

# for i, root_folder_path in enumerate(root_folder_paths):
#     print(f'Processing {i + 1}/5 Folder.')
#     for j, ntc_folder_name in enumerate(os.listdir(root_folder_path)):
#         print(f'Processing {j + 1}/100 Internal Folder.')
#         ntc_folder_path = os.path.join(root_folder_path, ntc_folder_name)

#         # Define the pattern to search for XML files inside the folder.
#         xml_files_pattern = os.path.join(ntc_folder_path, "*.xml")

#         # Use the glob module to find all XML files matching the pattern.
#         xml_files_list = glob.glob(xml_files_pattern)

#         # Process each XML file
#         for k, xml_file_path in enumerate(xml_files_list):
#             print(f"Processing XML file {k + 1}/{len(xml_files_list)}: {xml_file_path}")
#             try:
#                 # Read the XML content from the file
#                 with open(xml_file_path, 'r') as file:
#                     xml_data = file.read()

#                 # Extract tags from the XML data
#                 document = extract_tags(xml_data)
#                 all_documents.append(document)

#                 # Check if it's time to save the chunk to the Pickle file
#                 if len(all_documents) >= chunk_size:
#                     # Save the extracted information to a Pickle file
#                     with open('path_to_save_data', 'ab') as file:
#                         pickle.dump(all_documents, file)

#                     # Clear the all_documents list to free up memory
#                     all_documents = []
#             except Exception as e:
#                 # Handle any exceptions that might occur during processing
#                 print(f"Error processing XML file: {xml_file_path}")
#                 print(f"Error details: {str(e)}")

# # Save any remaining data to the Pickle file
# if all_documents:
#     with open(path_to_save_data, 'ab') as file:
#         pickle.dump(all_documents, file)

# print("Extraction and Pickling complete!")

# %% [markdown]
# ## Load the Pickle file in a dataframe to use it with PyTerrier

# %%
# Specify the path to the pickle file
pickle_file_path = ''

# Load the data from the pickle file into a list of dictionaries
with open(pickle_file_path, 'rb') as file:
    extracted_data = []
    while True:
        try:
            document = pickle.load(file)
            extracted_data.extend(document)
        except EOFError:
            break

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(extracted_data)

# %% [markdown]
# # Downloading the Clinical trials 2021 collection [Start Here]
#
# 2 GBs --> 20 sec

# %%
# !gdown --id 1oi3mnz6PQVt-tEMR6IQnqC0ab9IZ1iXx
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1oi3mnz6PQVt-tEMR6IQnqC0ab9IZ1iXx
# To: /content/extracted_information.pkl
# 100% 2.20G/2.20G [00:18<00:00, 120MB/s]

# %% [markdown]
# # Load the Dataframe
#
# 2 GBs --> 18 secs, 375580 Documents

# %%
import pandas as pd
import pickle

# Specify the path to the pickle file
pickle_file_path = '/content/extracted_information.pkl'

# Load the data from the pickle file into a list of dictionaries
with open(pickle_file_path, 'rb') as file:
    extracted_data = []
    while True:
        try:
            document = pickle.load(file)
            extracted_data.extend(document)
        except EOFError:
            break

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(extracted_data)

# Now 'df' is a Pandas DataFrame that contains the extracted information from the XML files.
# You can use standard Pandas DataFrame operations to analyze and manipulate the data.
# For example, you can print the first few rows of the DataFrame:
display(df.head())
print(f'Total number of documents: {len(df)}')
# Out:
#         nct_id                                        brief_title  \
# 0  NCT00976963  Single Dose Monurol for Treatment of Acute Cys...
# 1  NCT00976573  Carboplatin, Paclitaxel, and Bevacizumab With ...
# 2  NCT00971139  Implementing Online Patient-Provider Communica...
# 3  NCT00977769  Carbetocin Versus Oxytocin and Hemodynamic Eff...
# 4  NCT00976924         Clinical Test of Blood Glucose Test Strips
#
#                                       official_title  \
# 0  Single Dose Monurol for Treatment of Acute Cys...
# 1  A Randomized Phase II Trial of Carboplatin, Pa...
# 2  Implementing Online Patient-Provider Communica...
# 3  Hemodynamic Effects of Carbetocin 100 µg, Oxyt...
# 4         Clinical Test of Blood Glucose Test Strips
#
#                                        brief_summary  \
# 0  Urinary tract infecton (UTI) is a very common ...
# 1  This randomized phase II trial is studying how...
# 2  This interdisciplinary, international collabor...
# 3  A randomized double-blind trial of oxytocin 5 ...
# 4  Blood glucose test strips are tested with the ...
#
#                                 detailed_description      study_type  \
# 0  Procedures subjects will undergo once they hav...  Interventional
# 1  OBJECTIVES:\r\n\r\n      Primary\r\n\r\n      ...  Interventional
# 2  A rapidly growing research literature document...  Interventional
# 3  Healthy pregnant women sheduled for elective c...  Interventional
# 4                                                     Interventional
#
#   study_design_info_primary_purpose                             condition  \
# 0                         Treatment               Urinary Tract Infection
# 1                         Treatment                       Melanoma (Skin)
# 2                   Supportive Care                                Cancer
# 3                         Treatment  Effects of; Anesthesia, in Pregnancy
# 4                        Diagnostic                              Diabetes
#
#   intervention_intervention_type intervention_intervention_name  \
# 0                           Drug                     Fosfomycin
# 1                     Biological                    bevacizumab
# 2                     Behavioral      Access to an OPPC service
# 3                           Drug              carbetocin 100 µg
# 4                         Device          blood glucose monitor
#
#                                             location  \
# 0                           University of Washington
# 1                             Mayo Clinic Scottsdale
# 2          Oslo University Hospital - Rikshospitalet
# 3  Division of Anaesthesia and Intensive Care Med...
# 4        Tianjin Medical University general hospital
#
#                                       trials_keyword  \
# 0                                                UTI
# 1         Stage IV Skin Melanoma, recurrent melanoma
# 2  Online patient-provider communication, Organiz...
# 3  cesarean delivery, blood pressure, cardiac output
# 4                                      blood glucose
#
#   condition_browse_mesh_term  \
# 0   Urinary Tract Infections
# 1                   Melanoma
# 2
# 3
# 4
#
#                       intervention_browse_mesh_term  \
# 0                                        Fosfomycin
# 1  Paclitaxel, Bevacizumab, Carboplatin, Everolimus
# 2
# 3                              Oxytocin, Carbetocin
# 4
#
#                                 eligibility_criteria  \
# 0  Inclusion Criteria:\r\n\r\n          -  Non pr...
# 1  Inclusion Criteria:\r\n\r\n          -  Histol...
# 2  Inclusion Criteria:\r\n\r\n          -  18 yea...
# 3  Inclusion Criteria:\r\n\r\n          -  Health...
# 4  Inclusion Criteria:\r\n\r\n          -  The pa...
#
#                       eligibility_inclusion_criteria  \
# 0  :\r\n\r\n          -  Non pregnant women in go...
# 1  :\r\n\r\n          -  Histologic proof of stag...
# 2  :\r\n\r\n          -  18 years of age.\r\n\r\n...
# 3  :\r\n\r\n          -  Healthy pregnant women f...
# 4  :\r\n\r\n          -  The patients with blood ...
#
#                       eligibility_exclusion_criteria eligibility_gender  \
# 0  :\r\n\r\n          -  Pregnant, lactating, or ...             Female
# 1  -  Prior treatment with agents disrupting vasc...                All
# 2  :\r\n\r\n          -  Excluded are patients wh...                All
# 3  :\r\n\r\n          -  Bleeding disorders\r\n\r...             Female
# 4  :\r\n\r\n          -  The patients with blood ...                All
#
#   eligibility_minimum_age eligibility_maximum_age  \
# 0                18 Years                45 Years
# 1                18 Years                     N/A
# 2                18 Years                     N/A
# 3                18 Years                50 Years
# 4                22 Years                78 Years
#
#   eligibility_healthy_volunteers
# 0     Accepts Healthy Volunteers
# 1                             No
# 2                             No
# 3                             No
# 4     Accepts Healthy Volunteers
# Total number of documents: 375580

# %% [markdown]
# # Analyze the data

# %% [markdown]
# ## Installing PyTerrier

# %%
# !pip install python-terrier
import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])

from pyterrier.measures import *
# Out:
# Requirement already satisfied: python-terrier in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.5.3)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from python-terrier) (4.66.1)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.5.0)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.14)
# Requirement already satisfied: chest in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.3.2)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier) (10.1.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.14.0)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.11.2)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (2.3.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir-measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2023.7.22)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.10/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier) (2.1.3)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (23.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)

# %% [markdown]
# ## Creating a field to index per document

# %%
## Rename the ntc_id column to docno
df.rename(columns={'nct_id': 'docno'}, inplace=True)
display(df.keys())

## Merge the titles, and the summary in one text
columns_to_combine = ["brief_title", "official_title", "brief_summary", "detailed_description", "condition", "condition_browse_mesh_term", "eligibility_gender", "eligibility_criteria"]
df["text"] = ""
for col in columns_to_combine:
  print(f"Merge col {col}")
  df["text"] = df["text"] + " " + df[col].fillna("").astype(str)

# df = df.head(50_000)
# display(df)
# Out:
# Index(['docno', 'brief_title', 'official_title', 'brief_summary',
#        'detailed_description', 'study_type',
#        'study_design_info_primary_purpose', 'condition',
#        'intervention_intervention_type', 'intervention_intervention_name',
#        'location', 'trials_keyword', 'condition_browse_mesh_term',
#        'intervention_browse_mesh_term', 'eligibility_criteria',
#        'eligibility_inclusion_criteria', 'eligibility_exclusion_criteria',
#        'eligibility_gender', 'eligibility_minimum_age',
#        'eligibility_maximum_age', 'eligibility_healthy_volunteers', 'text'],
#       dtype='object')
# Merge col brief_title
# Merge col official_title
# Merge col brief_summary
# Merge col detailed_description
# Merge col condition
# Merge col condition_browse_mesh_term
# Merge col eligibility_gender
# Merge col eligibility_criteria

# %% [markdown]
# In the following cell, we index the dataframe's documents. The index, with all its data structures, is written into a directory called `index`.
#
# [10 minutes - Whole Collection]

# %%
# !rm -r ./content/index

# %%
##Allows to set a property in Terrier’s global properties configuration. Example:
pt.set_property("termpipelines", "PorterStemmer, stopwords")

# Index the text, record the docnos and the raw text as metadata
pd_indexer = pt.DFIndexer("./content/index", overwrite=True, verbose=True)
indexref = pd_indexer.index(df["text"], df[["docno"]])

##Printing the files related to the index
# !ls -lh content/index/
# Out:
#   0%|          | 0/375580 [00:00<?, ?documents/s]
# /usr/local/lib/python3.10/dist-packages/pyterrier/index.py:628: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, value in meta_column[1].iteritems():
# total 195M
# -rw-r--r-- 1 root root  71M Aug 30 15:18 data.direct.bf
# -rw-r--r-- 1 root root 6.1M Aug 30 15:18 data.document.fsarrayfile
# -rw-r--r-- 1 root root  66M Aug 30 15:19 data.inverted.bf
# -rw-r--r-- 1 root root  26M Aug 30 15:19 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root 1017 Aug 30 15:19 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root 1.3M Aug 30 15:19 data.lexicon.fsomapid
# -rw-r--r-- 1 root root  14M Aug 30 15:18 data.meta-0.fsomapfile
# -rw-r--r-- 1 root root 2.9M Aug 30 15:18 data.meta.idx
# -rw-r--r-- 1 root root 9.7M Aug 30 15:18 data.meta.zdata
# -rw-r--r-- 1 root root 4.1K Aug 30 15:19 data.properties

# %% [markdown]
# Printing some statistics

# %% [markdown]
# # Loading queries and qrels

# %% [markdown]
# We will use ir_datasets to obtain the queries and the qrels
# https://ir-datasets.com/

# %%
# Queries
# !pip install --upgrade ir_datasets
dataset = pt.get_dataset('irds:clinicaltrials/2021/trec-ct-2022')
queries = dataset.get_topics(variant='text')
display(queries[:10])
# Out:
# Requirement already satisfied: ir_datasets in /usr/local/lib/python3.10/dist-packages (0.5.5)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.11.2)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.3.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.9.3)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (1.23.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (6.0.1)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.66.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets) (0.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->ir_datasets) (2023.7.22)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir_datasets) (1.0.0)
#   qid                                              query
# 0   1  a 19 year old male came to clinic with some se...
# 1   2  a 32 year old woman comes to the hospital with...
# 2   3  a 51 year old man comes to the office complain...
# 3   4  a 66 year old woman comes to the office due to...
# 4   5  a 23 year old man comes to the emergency depar...
# 5   6  a 61 year old man comes to the clinic due to n...
# 6   7  a 3 year old girl is brought to the clinic by ...
# 7   8  a 7 month old boy is brought to emergency by h...
# 8   9  a 67 year old woman comes to the clinic due to...
# 9  10  a 19 year old girl comes to the clinic due to ...

# %%
#Qrels
# !gdown --id 1RYHxr2sM9Hd2C2iRI_NXzO4RY71Adu-p

path_to_qrels = 'clinical_qrels22.txt'
qrels = pd.read_csv(path_to_qrels, names=['qid','Q0','docno','label'],sep=" ",header=None)
qrels = qrels.drop(columns=['Q0'])
qrels["qid"] = qrels["qid"].astype(str)
qrels["docno"] = qrels["docno"].astype(str)
display(qrels[:10])
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1RYHxr2sM9Hd2C2iRI_NXzO4RY71Adu-p
# To: /content/clinical_qrels22.txt
# 100% 666k/666k [00:00<00:00, 118MB/s]
#   qid        docno  label
# 0   1  NCT00000409      0
# 1   1  NCT00001148      0
# 2   1  NCT00001181      0
# 3   1  NCT00001202      0
# 4   1  NCT00001270      0
# 5   1  NCT00001412      1
# 6   1  NCT00001417      0
# 7   1  NCT00001721      0
# 8   1  NCT00002459      0
# 9   1  NCT00002619      0

# %%
qrels['label'].value_counts()
# Out:
# 0    28419
# 2     3939
# 1     3036
# Name: label, dtype: int64

# %%
qrels_relevance = qrels.copy()
qrels_relevance["label"] = qrels_relevance["label"].map({0:0, 1:1, 2:1})
qrels_relevance[:10]
# Out:
#   qid        docno  label
# 0   1  NCT00000409      0
# 1   1  NCT00001148      0
# 2   1  NCT00001181      0
# 3   1  NCT00001202      0
# 4   1  NCT00001270      0
# 5   1  NCT00001412      1
# 6   1  NCT00001417      0
# 7   1  NCT00001721      0
# 8   1  NCT00002459      0
# 9   1  NCT00002619      0

# %%
qrels_eligible = qrels.copy()
qrels_eligible = qrels_eligible[qrels_eligible["label"] != 0]
qrels_eligible["label"] = qrels_eligible["label"].map({1:0, 2:1})
qrels_eligible[:10]
# Out:
#    qid        docno  label
# 5    1  NCT00001412      0
# 32   1  NCT00004335      0
# 49   1  NCT00064987      0
# 51   1  NCT00070733      0
# 52   1  NCT00080483      0
# 56   1  NCT00104572      0
# 57   1  NCT00112151      0
# 60   1  NCT00119483      0
# 65   1  NCT00136695      0
# 66   1  NCT00140153      0

# %% [markdown]
# # Candidate retrieval

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25", properties={"termpipelines" : "Stopwords,PorterStemmer"}, verbose=True)
rm3  = pt.rewrite.RM3(index, fb_terms=30, fb_docs=20, verbose=True)

candidate_retrieval_1 = bm25
candidate_retrieval_2 = (candidate_retrieval_1 >> rm3 >> candidate_retrieval_1 >> pt.rewrite.reset())

# %%
pt.Experiment(
    [
      candidate_retrieval_1,
      candidate_retrieval_2,
    ],
    names=[
        "candidate retr. 1",
        "candidate retr. 2",
    ],
    eval_metrics= [
        P(rel=2)@10, R(rel=2)@10, R(rel=2)@25, R(rel=2)@100, R(rel=2)@500, R(rel=2)@1000
    ],
    topics=queries,
    qrels=qrels,
    baseline=0,
    perquery = False,
    correction='b',
    highlight= 'color',
    verbose=True,
)
# Out:
# pt.Experiment:   0%|          | 0/2 [00:00<?, ?system/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# Transformer:   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# <style type="text/css">
# #T_63161_row0_col3, #T_63161_row1_col1, #T_63161_row1_col2, #T_63161_row1_col4, #T_63161_row1_col5, #T_63161_row1_col6, #T_63161_row1_col7, #T_63161_row1_col8, #T_63161_row1_col12, #T_63161_row1_col13, #T_63161_row1_col17, #T_63161_row1_col18, #T_63161_row1_col22, #T_63161_row1_col23, #T_63161_row1_col27, #T_63161_row1_col28, #T_63161_row1_col32, #T_63161_row1_col33 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_63161" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63161_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_63161_level0_col1" class="col_heading level0 col1" >P(rel=2)@10</th>
#       <th id="T_63161_level0_col2" class="col_heading level0 col2" >R(rel=2)@10</th>
#       <th id="T_63161_level0_col3" class="col_heading level0 col3" >R(rel=2)@25</th>
#       <th id="T_63161_level0_col4" class="col_heading level0 col4" >R(rel=2)@100</th>
#       <th id="T_63161_level0_col5" class="col_heading level0 col5" >R(rel=2)@500</th>
#       <th id="T_63161_level0_col6" class="col_heading level0 col6" >R(rel=2)@1000</th>
#       <th id="T_63161_level0_col7" class="col_heading level0 col7" >P(rel=2)@10 +</th>
#       <th id="T_63161_level0_col8" class="col_heading level0 col8" >P(rel=2)@10 -</th>
#       <th id="T_63161_level0_col9" class="col_heading level0 col9" >P(rel=2)@10 p-value</th>
#       <th id="T_63161_level0_col10" class="col_heading level0 col10" >P(rel=2)@10 reject</th>
#       <th id="T_63161_level0_col11" class="col_heading level0 col11" >P(rel=2)@10 p-value corrected</th>
#       <th id="T_63161_level0_col12" class="col_heading level0 col12" >R(rel=2)@10 +</th>
#       <th id="T_63161_level0_col13" class="col_heading level0 col13" >R(rel=2)@10 -</th>
#       <th id="T_63161_level0_col14" class="col_heading level0 col14" >R(rel=2)@10 p-value</th>
#       <th id="T_63161_level0_col15" class="col_heading level0 col15" >R(rel=2)@10 reject</th>
#       <th id="T_63161_level0_col16" class="col_heading level0 col16" >R(rel=2)@10 p-value corrected</th>
#       <th id="T_63161_level0_col17" class="col_heading level0 col17" >R(rel=2)@25 +</th>
#       <th id="T_63161_level0_col18" class="col_heading level0 col18" >R(rel=2)@25 -</th>
#       <th id="T_63161_level0_col19" class="col_heading level0 col19" >R(rel=2)@25 p-value</th>
#       <th id="T_63161_level0_col20" class="col_heading level0 col20" >R(rel=2)@25 reject</th>
#       <th id="T_63161_level0_col21" class="col_heading level0 col21" >R(rel=2)@25 p-value corrected</th>
#       <th id="T_63161_level0_col22" class="col_heading level0 col22" >R(rel=2)@100 +</th>
#       <th id="T_63161_level0_col23" class="col_heading level0 col23" >R(rel=2)@100 -</th>
#       <th id="T_63161_level0_col24" class="col_heading level0 col24" >R(rel=2)@100 p-value</th>
#       <th id="T_63161_level0_col25" class="col_heading level0 col25" >R(rel=2)@100 reject</th>
#       <th id="T_63161_level0_col26" class="col_heading level0 col26" >R(rel=2)@100 p-value corrected</th>
#       <th id="T_63161_level0_col27" class="col_heading level0 col27" >R(rel=2)@500 +</th>
#       <th id="T_63161_level0_col28" class="col_heading level0 col28" >R(rel=2)@500 -</th>
#       <th id="T_63161_level0_col29" class="col_heading level0 col29" >R(rel=2)@500 p-value</th>
#       <th id="T_63161_level0_col30" class="col_heading level0 col30" >R(rel=2)@500 reject</th>
#       <th id="T_63161_level0_col31" class="col_heading level0 col31" >R(rel=2)@500 p-value corrected</th>
#       <th id="T_63161_level0_col32" class="col_heading level0 col32" >R(rel=2)@1000 +</th>
#       <th id="T_63161_level0_col33" class="col_heading level0 col33" >R(rel=2)@1000 -</th>
#       <th id="T_63161_level0_col34" class="col_heading level0 col34" >R(rel=2)@1000 p-value</th>
#       <th id="T_63161_level0_col35" class="col_heading level0 col35" >R(rel=2)@1000 reject</th>
#       <th id="T_63161_level0_col36" class="col_heading level0 col36" >R(rel=2)@1000 p-value corrected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63161_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63161_row0_col0" class="data row0 col0" >candidate retr. 1</td>
#       <td id="T_63161_row0_col1" class="data row0 col1" >0.208000</td>
#       <td id="T_63161_row0_col2" class="data row0 col2" >0.032176</td>
#       <td id="T_63161_row0_col3" class="data row0 col3" >0.054195</td>
#       <td id="T_63161_row0_col4" class="data row0 col4" >0.079929</td>
#       <td id="T_63161_row0_col5" class="data row0 col5" >0.107472</td>
#       <td id="T_63161_row0_col6" class="data row0 col6" >0.112412</td>
#       <td id="T_63161_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_63161_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_63161_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_63161_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_63161_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_63161_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_63161_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_63161_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_63161_row0_col15" class="data row0 col15" >False</td>
#       <td id="T_63161_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_63161_row0_col17" class="data row0 col17" >nan</td>
#       <td id="T_63161_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_63161_row0_col19" class="data row0 col19" >nan</td>
#       <td id="T_63161_row0_col20" class="data row0 col20" >False</td>
#       <td id="T_63161_row0_col21" class="data row0 col21" >nan</td>
#       <td id="T_63161_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_63161_row0_col23" class="data row0 col23" >nan</td>
#       <td id="T_63161_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_63161_row0_col25" class="data row0 col25" >False</td>
#       <td id="T_63161_row0_col26" class="data row0 col26" >nan</td>
#       <td id="T_63161_row0_col27" class="data row0 col27" >nan</td>
#       <td id="T_63161_row0_col28" class="data row0 col28" >nan</td>
#       <td id="T_63161_row0_col29" class="data row0 col29" >nan</td>
#       <td id="T_63161_row0_col30" class="data row0 col30" >False</td>
#       <td id="T_63161_row0_col31" class="data row0 col31" >nan</td>
#       <td id="T_63161_row0_col32" class="data row0 col32" >nan</td>
#       <td id="T_63161_row0_col33" class="data row0 col33" >nan</td>
#       <td id="T_63161_row0_col34" class="data row0 col34" >nan</td>
#       <td id="T_63161_row0_col35" class="data row0 col35" >False</td>
#       <td id="T_63161_row0_col36" class="data row0 col36" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_63161_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63161_row1_col0" class="data row1 col0" >candidate retr. 2</td>
#       <td id="T_63161_row1_col1" class="data row1 col1" >0.246000</td>
#       <td id="T_63161_row1_col2" class="data row1 col2" >0.035095</td>
#       <td id="T_63161_row1_col3" class="data row1 col3" >0.052845</td>
#       <td id="T_63161_row1_col4" class="data row1 col4" >0.082250</td>
#       <td id="T_63161_row1_col5" class="data row1 col5" >0.110824</td>
#       <td id="T_63161_row1_col6" class="data row1 col6" >0.120399</td>
#       <td id="T_63161_row1_col7" class="data row1 col7" >18.000000</td>
#       <td id="T_63161_row1_col8" class="data row1 col8" >10.000000</td>
#       <td id="T_63161_row1_col9" class="data row1 col9" >0.076156</td>
#       <td id="T_63161_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_63161_row1_col11" class="data row1 col11" >0.152312</td>
#       <td id="T_63161_row1_col12" class="data row1 col12" >18.000000</td>
#       <td id="T_63161_row1_col13" class="data row1 col13" >10.000000</td>
#       <td id="T_63161_row1_col14" class="data row1 col14" >0.538192</td>
#       <td id="T_63161_row1_col15" class="data row1 col15" >False</td>
#       <td id="T_63161_row1_col16" class="data row1 col16" >1.000000</td>
#       <td id="T_63161_row1_col17"

# %%
best_candidate_retrieval = candidate_retrieval_2

# %% [markdown]
# # Relevance re-ranking

# %%
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_t5.git
# Out:
# Collecting git+https://github.com/terrierteam/pyterrier_t5.git
#   Cloning https://github.com/terrierteam/pyterrier_t5.git to /tmp/pip-req-build-bquuwnue
#   Running command git clone --filter=blob:none --quiet https://github.com/terrierteam/pyterrier_t5.git /tmp/pip-req-build-bquuwnue
#   Resolved https://github.com/terrierteam/pyterrier_t5.git to commit 63756ebc2968ab03f46a61f0b391e27873226d75
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-terrier>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (0.9.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (1.5.3)
# Requirement already satisfied: transformers>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (4.32.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (2.0.1+cu118)
# Requirement already satisfied: sentencepiece>=0.1.95 in /usr/local/lib/python3.10/dist-packages (from pyterrier-t5==0.0.1) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.23.5)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.66.1)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.5.0)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.2.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.2.14)
# Requirement already satisfied: chest in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.3.2)
# Requirement already satisfied: nptyping==1.4.4 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.4.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (10.1.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.14.0)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.10/dist-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from nptyping==1.4.4->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.9.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.3.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyterrier-t5==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyterrier-t5==0.0.1) (2023.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->pyterrier-t5==0.0.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->pyterrier-t5==0.0.1) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->pyterrier-t5==0.0.1) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers>=4.0.0->pyterrier-t5==0.0.1) (2023.6.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.11.2)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.3.2)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.9.3)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.5)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /usr/local/lib/python3.10/dist-packages (from ir-measures>=0.3.1->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pyterrier-t5==0.0.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2023.7.22)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.10/dist-packages (from chest->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.3)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from matchpy->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pyterrier-t5==0.0.1) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.4.1)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.0)

# %%
from pyterrier_t5 import MonoT5ReRanker
MonoT5ReRanker.__repr__ = lambda self: "monoT5"
mono_t5 = MonoT5ReRanker("castorini/monot5-base-msmarco", batch_size=128, verbose=True)

# %%
from dataclasses import dataclass

df_t = df[["docno", "text"]]

@dataclass(frozen=True)
class GetText(pt.Transformer):

  def transform(self, res):
    res = res.merge(df_t, how="inner", on="docno")
    return res

  def __repr__(self):
    return "GetText()"

# %%
relevance_reranking_1 = best_candidate_retrieval
relevance_reranking_2 = ~((best_candidate_retrieval % 100 >> GetText() >> mono_t5) ^ best_candidate_retrieval)

# %%
pt.Experiment(
    [
      relevance_reranking_1,
      relevance_reranking_2,
    ],
    names=[
        "rel. re-rank 1",
        "rel. re-rank 2",
    ],
    eval_metrics= [
        P(rel=1)@10, nDCG@10, Rprec(rel=1), RR(rel=1),
    ],
    topics=queries,
    qrels=qrels_relevance,
    baseline=0,
    perquery = False,
    correction='b',
    highlight= 'color',
    verbose=True,
)
# Out:
# pt.Experiment:   0%|          | 0/2 [00:00<?, ?system/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# Transformer:   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# Transformer:   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# monoT5:   0%|          | 0/40 [00:00<?, ?batches/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1300 > 512). Running this sequence through the model will result in indexing errors
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# Transformer:   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# <style type="text/css">
# #T_6347a_row0_col1, #T_6347a_row0_col2, #T_6347a_row0_col3, #T_6347a_row0_col4, #T_6347a_row1_col5, #T_6347a_row1_col6, #T_6347a_row1_col10, #T_6347a_row1_col11, #T_6347a_row1_col15, #T_6347a_row1_col16, #T_6347a_row1_col20, #T_6347a_row1_col21 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6347a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6347a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_6347a_level0_col1" class="col_heading level0 col1" >Rprec</th>
#       <th id="T_6347a_level0_col2" class="col_heading level0 col2" >RR</th>
#       <th id="T_6347a_level0_col3" class="col_heading level0 col3" >P@10</th>
#       <th id="T_6347a_level0_col4" class="col_heading level0 col4" >nDCG@10</th>
#       <th id="T_6347a_level0_col5" class="col_heading level0 col5" >Rprec +</th>
#       <th id="T_6347a_level0_col6" class="col_heading level0 col6" >Rprec -</th>
#       <th id="T_6347a_level0_col7" class="col_heading level0 col7" >Rprec p-value</th>
#       <th id="T_6347a_level0_col8" class="col_heading level0 col8" >Rprec reject</th>
#       <th id="T_6347a_level0_col9" class="col_heading level0 col9" >Rprec p-value corrected</th>
#       <th id="T_6347a_level0_col10" class="col_heading level0 col10" >RR +</th>
#       <th id="T_6347a_level0_col11" class="col_heading level0 col11" >RR -</th>
#       <th id="T_6347a_level0_col12" class="col_heading level0 col12" >RR p-value</th>
#       <th id="T_6347a_level0_col13" class="col_heading level0 col13" >RR reject</th>
#       <th id="T_6347a_level0_col14" class="col_heading level0 col14" >RR p-value corrected</th>
#       <th id="T_6347a_level0_col15" class="col_heading level0 col15" >P@10 +</th>
#       <th id="T_6347a_level0_col16" class="col_heading level0 col16" >P@10 -</th>
#       <th id="T_6347a_level0_col17" class="col_heading level0 col17" >P@10 p-value</th>
#       <th id="T_6347a_level0_col18" class="col_heading level0 col18" >P@10 reject</th>
#       <th id="T_6347a_level0_col19" class="col_heading level0 col19" >P@10 p-value corrected</th>
#       <th id="T_6347a_level0_col20" class="col_heading level0 col20" >nDCG@10 +</th>
#       <th id="T_6347a_level0_col21" class="col_heading level0 col21" >nDCG@10 -</th>
#       <th id="T_6347a_level0_col22" class="col_heading level0 col22" >nDCG@10 p-value</th>
#       <th id="T_6347a_level0_col23" class="col_heading level0 col23" >nDCG@10 reject</th>
#       <th id="T_6347a_level0_col24" class="col_heading level0 col24" >nDCG@10 p-value corrected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6347a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6347a_row0_col0" class="data row0 col0" >rel. re-rank 1</td>
#       <td id="T_6347a_row0_col1" class="data row0 col1" >0.077887</td>
#       <td id="T_6347a_row0_col2" class="data row0 col2" >0.548553</td>
#       <td id="T_6347a_row0_col3" class="data row0 col3" >0.360000</td>
#       <td id="T_6347a_row0_col4" class="data row0 col4" >0.378741</td>
#       <td id="T_6347a_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_6347a_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_6347a_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_6347a_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_6347a_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_6347a_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_6347a_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_6347a_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_6347a_row0_col13" class="data row0 col13" >False</td>
#       <td id="T_6347a_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_6347a_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_6347a_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_6347a_row0_col17" class="data row0 col17" >nan</td>
#       <td id="T_6347a_row0_col18" class="data row0 col18" >False</td>
#       <td id="T_6347a_row0_col19" class="data row0 col19" >nan</td>
#       <td id="T_6347a_row0_col20" class="data row0 col20" >nan</td>
#       <td id="T_6347a_row0_col21" class="data row0 col21" >nan</td>
#       <td id="T_6347a_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_6347a_row0_col23" class="data row0 col23" >False</td>
#       <td id="T_6347a_row0_col24" class="data row0 col24" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6347a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6347a_row1_col0" class="data row1 col0" >rel. re-rank 2</td>
#       <td id="T_6347a_row1_col1" class="data row1 col1" >0.076940</td>
#       <td id="T_6347a_row1_col2" class="data row1 col2" >0.486379</td>
#       <td id="T_6347a_row1_col3" class="data row1 col3" >0.308000</td>
#       <td id="T_6347a_row1_col4" class="data row1 col4" >0.325485</td>
#       <td id="T_6347a_row1_col5" class="data row1 col5" >7.000000</td>
#       <td id="T_6347a_row1_col6" class="data row1 col6" >3.000000</td>
#       <td id="T_6347a_row1_col7" class="data row1 col7" >0.734941</td>
#       <td id="T_6347a_row1_col8" class="data row1 col8" >False</td>
#       <td id="T_6347a_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_6347a_row1_col10" class="data row1 col10" >11.000000</td>
#       <td id="T_6347a_row1_col11" class="data row1 col11" >17.000000</td>
#       <td id="T_6347a_row1_col12" class="data row1 col12" >0.301395</td>
#       <td id="T_6347a_row1_col13" class="data row1 col13" >False</td>
#       <td id="T_6347a_row1_col14" class="data row1 col14" >0.602789</td>
#       <td id="T_6347a_row1_col15" class="data row1 col15" >12.000000</td>
#       <td id="T_6347a_row1_col16" class="data row1 col16" >23.000000</td>
#       <td id="T_6347a_row1_col17" class="data row1 col17" >0.124015</td>
#       <td id="T_6347a_row1_col18" class="data row1 col18" >False</td>
#       <td id="T_6347a_row1_col19" class="data row1 col19" >0.248030</td>
#       <td id="T_6347a_row1_col20" class="data row1 col20" >17.000000</td>
#       <td id="T_6347a_row1_col21" class="data row1 col21" >24.000000</td>
#       <td id="T_6347a_row1_col22" class="data row1 col22" >0.157692</td>
#       <td id="T_6347a_row1_col23" class="data row1 col23" >False</td>
#       <td id="T_6347a_row1_col24" class="data row1 col24" >0.315385</td>
#     </tr>
#   </tbody>
# </table>

# %%
pt.Experiment(
    [
      relevance_reranking_1,
      relevance_reranking_2,
    ],
    names=[
        "rel. re-rank 1",
        "rel. re-rank 2",
    ],
    eval_metrics= [
        # P(rel=2)@10, nDCG@10, Rprec(rel=2), RR(rel=2),
        P(rel=2)@10, R(rel=2)@10, R(rel=2)@25, R(rel=2)@100, R(rel=2)@500, R(rel=2)@1000
    ],
    topics=queries,
    qrels=qrels,
    baseline=0,
    perquery = False,
    correction='b',
    highlight= 'color',
    verbose=True,
)
# Out:
# pt.Experiment:   0%|          | 0/2 [00:00<?, ?system/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# Transformer:   0%|          | 0/50 [00:00<?, ?q/s]
# BR(BM25):   0%|          | 0/50 [00:00<?, ?q/s]
# <style type="text/css">
# #T_2c28a_row0_col1, #T_2c28a_row0_col2, #T_2c28a_row0_col3, #T_2c28a_row0_col4, #T_2c28a_row0_col5, #T_2c28a_row0_col6, #T_2c28a_row1_col7, #T_2c28a_row1_col8, #T_2c28a_row1_col12, #T_2c28a_row1_col13, #T_2c28a_row1_col17, #T_2c28a_row1_col18, #T_2c28a_row1_col22, #T_2c28a_row1_col23, #T_2c28a_row1_col27, #T_2c28a_row1_col28, #T_2c28a_row1_col32, #T_2c28a_row1_col33 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c28a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c28a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2c28a_level0_col1" class="col_heading level0 col1" >P(rel=2)@10</th>
#       <th id="T_2c28a_level0_col2" class="col_heading level0 col2" >R(rel=2)@10</th>
#       <th id="T_2c28a_level0_col3" class="col_heading level0 col3" >R(rel=2)@25</th>
#       <th id="T_2c28a_level0_col4" class="col_heading level0 col4" >R(rel=2)@100</th>
#       <th id="T_2c28a_level0_col5" class="col_heading level0 col5" >R(rel=2)@500</th>
#       <th id="T_2c28a_level0_col6" class="col_heading level0 col6" >R(rel=2)@1000</th>
#       <th id="T_2c28a_level0_col7" class="col_heading level0 col7" >P(rel=2)@10 +</th>
#       <th id="T_2c28a_level0_col8" class="col_heading level0 col8" >P(rel=2)@10 -</th>
#       <th id="T_2c28a_level0_col9" class="col_heading level0 col9" >P(rel=2)@10 p-value</th>
#       <th id="T_2c28a_level0_col10" class="col_heading level0 col10" >P(rel=2)@10 reject</th>
#       <th id="T_2c28a_level0_col11" class="col_heading level0 col11" >P(rel=2)@10 p-value corrected</th>
#       <th id="T_2c28a_level0_col12" class="col_heading level0 col12" >R(rel=2)@10 +</th>
#       <th id="T_2c28a_level0_col13" class="col_heading level0 col13" >R(rel=2)@10 -</th>
#       <th id="T_2c28a_level0_col14" class="col_heading level0 col14" >R(rel=2)@10 p-value</th>
#       <th id="T_2c28a_level0_col15" class="col_heading level0 col15" >R(rel=2)@10 reject</th>
#       <th id="T_2c28a_level0_col16" class="col_heading level0 col16" >R(rel=2)@10 p-value corrected</th>
#       <th id="T_2c28a_level0_col17" class="col_heading level0 col17" >R(rel=2)@25 +</th>
#       <th id="T_2c28a_level0_col18" class="col_heading level0 col18" >R(rel=2)@25 -</th>
#       <th id="T_2c28a_level0_col19" class="col_heading level0 col19" >R(rel=2)@25 p-value</th>
#       <th id="T_2c28a_level0_col20" class="col_heading level0 col20" >R(rel=2)@25 reject</th>
#       <th id="T_2c28a_level0_col21" class="col_heading level0 col21" >R(rel=2)@25 p-value corrected</th>
#       <th id="T_2c28a_level0_col22" class="col_heading level0 col22" >R(rel=2)@100 +</th>
#       <th id="T_2c28a_level0_col23" class="col_heading level0 col23" >R(rel=2)@100 -</th>
#       <th id="T_2c28a_level0_col24" class="col_heading level0 col24" >R(rel=2)@100 p-value</th>
#       <th id="T_2c28a_level0_col25" class="col_heading level0 col25" >R(rel=2)@100 reject</th>
#       <th id="T_2c28a_level0_col26" class="col_heading level0 col26" >R(rel=2)@100 p-value corrected</th>
#       <th id="T_2c28a_level0_col27" class="col_heading level0 col27" >R(rel=2)@500 +</th>
#       <th id="T_2c28a_level0_col28" class="col_heading level0 col28" >R(rel=2)@500 -</th>
#       <th id="T_2c28a_level0_col29" class="col_heading level0 col29" >R(rel=2)@500 p-value</th>
#       <th id="T_2c28a_level0_col30" class="col_heading level0 col30" >R(rel=2)@500 reject</th>
#       <th id="T_2c28a_level0_col31" class="col_heading level0 col31" >R(rel=2)@500 p-value corrected</th>
#       <th id="T_2c28a_level0_col32" class="col_heading level0 col32" >R(rel=2)@1000 +</th>
#       <th id="T_2c28a_level0_col33" class="col_heading level0 col33" >R(rel=2)@1000 -</th>
#       <th id="T_2c28a_level0_col34" class="col_heading level0 col34" >R(rel=2)@1000 p-value</th>
#       <th id="T_2c28a_level0_col35" class="col_heading level0 col35" >R(rel=2)@1000 reject</th>
#       <th id="T_2c28a_level0_col36" class="col_heading level0 col36" >R(rel=2)@1000 p-value corrected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c28a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c28a_row0_col0" class="data row0 col0" >rel. re-rank 1</td>
#       <td id="T_2c28a_row0_col1" class="data row0 col1" >0.246000</td>
#       <td id="T_2c28a_row0_col2" class="data row0 col2" >0.035095</td>
#       <td id="T_2c28a_row0_col3" class="data row0 col3" >0.052845</td>
#       <td id="T_2c28a_row0_col4" class="data row0 col4" >0.082250</td>
#       <td id="T_2c28a_row0_col5" class="data row0 col5" >0.110824</td>
#       <td id="T_2c28a_row0_col6" class="data row0 col6" >0.120399</td>
#       <td id="T_2c28a_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_2c28a_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_2c28a_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_2c28a_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_2c28a_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_2c28a_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_2c28a_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_2c28a_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_2c28a_row0_col15" class="data row0 col15" >False</td>
#       <td id="T_2c28a_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_2c28a_row0_col17" class="data row0 col17" >nan</td>
#       <td id="T_2c28a_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_2c28a_row0_col19" class="data row0 col19" >nan</td>
#       <td id="T_2c28a_row0_col20" class="data row0 col20" >False</td>
#       <td id="T_2c28a_row0_col21" class="data row0 col21" >nan</td>
#       <td id="T_2c28a_row0_col22" class="data row0 col22" >nan</td>
#       <td id="T_2c28a_row0_col23" class="data row0 col23" >nan</td>
#       <td id="T_2c28a_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_2c28a_row0_col25" class="data row0 col25" >False</td>
#       <td id="T_2c28a_row0_col26" class="data row0 col26" >nan</td>
#       <td id="T_2c28a_row0_col27" class="data row0 col27" >nan</td>
#       <td id="T_2c28a_row0_col28" class="data row0 col28" >nan</td>
#       <td id="T_2c28a_row0_col29" class="data row0 col29" >nan</td>
#       <td id="T_2c28a_row0_col30" class="data row0 col30" >False</td>
#       <td id="T_2c28a_row0_col31" class="data row0 col31" >nan</td>
#       <td id="T_2c28a_row0_col32" class="data row0 col32" >nan</td>
#       <td id="T_2c28a_row0_col33" class="data row0 col33" >nan</td>
#       <td id="T_2c28a_row0_col34" class="data row0 col34" >nan</td>
#       <td id="T_2c28a_row0_col35" class="data row0 col35" >False</td>
#       <td id="T_2c28a_row0_col36" class="data row0 col36" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2c28a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c28a_row1_col0" class="data row1 col0" >rel. re-rank 2</td>
#       <td id="T_2c28a_row1_col1" class="data row1 col1" >0.202000</td>
#       <td id="T_2c28a_row1_col2" class="data row1 col2" >0.033455</td>
#       <td id="T_2c28a_row1_col3" class="data row1 col3" >0.051829</td>
#       <td id="T_2c28a_row1_col4" class="data row1 col4" >0.082250</td>
#       <td id="T_2c28a_row1_col5" class="data row1 col5" >0.110824</td>
#       <td id="T_2c28a_row1_col6" class="data row1 col6" >0.120399</td>
#       <td id="T_2c28a_row1_col7" class="data row1 col7" >9.000000</td>
#       <td id="T_2c28a_row1_col8" class="data row1 col8" >15.000000</td>
#       <td id="T_2c28a_row1_col9" class="data row1 col9" >0.072046</td>
#       <td id="T_2c28a_row1_col10" class="data row1 col10" >False</td>
#       <td id="T_2c28a_row1_col11" class="data row1 col11" >0.144092</td>
#       <td id="T_2c28a_row1_col12" class="data row1 col12" >9.000000</td>
#       <td id="T_2c28a_row1_col13" class="data row1 col13" >15.000000</td>
#       <td id="T_2c28a_row1_col14" class="data row1 col14" >0.724027</td>
#       <td id="T_2c28a_row1_col15" class="data row1 col15" >False</td>
#       <td id="T_2c28a_row1_col16" class="data row1 col16" >1.000000</td>
#       <td id="T_2c28a_row1_col17" class="

# %% [markdown]
# # Eligibility re-ranking

# %%
import ir_datasets as irds
dataset_2021 = irds.load('clinicaltrials/2021/trec-ct-2021')
qrels_2021 = pd.DataFrame([
    {
        "qid": qrel.query_id,
        "docno": qrel.doc_id,
        "label": qrel.relevance - 1,
    }
    for qrel in dataset_2021.qrels_iter()
    if qrel.relevance != 0
])
qrels_2021 = qrels_2021.merge(df[["docno", "eligibility_criteria"]], on="docno")
qrels_2021 = qrels_2021.merge(queries[["qid", "query"]], on="qid")
qrels_2021
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
qrels_2021

# %% [markdown]
# # Evaluation

# %%
display(res.head(25))
### Create Condesed list
Con_aggr_res = pd.merge(res, qrels, on=["qid",'docno'],how="left")
display(Con_aggr_res.head(25))
# display(Con_aggr_res.head(25))
Con_aggr_res = Con_aggr_res[Con_aggr_res['label'].notna()]

eval = pt.Utils.evaluate(Con_aggr_res, qrels,metrics=[AP@1000,P@5,P@10],perquery=False)
display(eval)
# Out:
#    qid   docid        docno  rank      score  \
# 0    1  132571  NCT01511588     0  42.294260
# 1    1  137074  NCT01689896     1  41.191565
# 2    1  150445  NCT01190904     2  40.756693
# 3    1  156096  NCT02612714     3  40.733572
# 4    1  358654  NCT04630275     4  39.414434
# 5    1   56037  NCT00104572     5  39.367162
# 6    1  128044  NCT01672411     6  38.929173
# 7    1  366889  NCT04036604     7  38.205295
# 8    1   68308  NCT00170339     8  37.978924
# 9    1  217263  NCT02529306     9  37.253048
# 10   1  142769  NCT01425541    10  37.082244
# 11   1   54289  NCT00752869    11  36.794108
# 12   1  323587  NCT04710238    12  36.325593
# 13   1  155799  NCT01270841    13  36.219013
# 14   1  318470  NCT04492553    14  36.218342
# 15   1  142638  NCT01427595    15  35.567633
# 16   1   32236  NCT00472940    16  35.560463
# 17   1   24666  NCT00223860    17  35.364775
# 18   1  297446  NCT03528538    18  35.360187
# 19   1   35620  NCT00392756    19  35.167350
# 20   1  277643  NCT03457740    20  34.959511
# 21   1   32926  NCT00522431    21  34.514782
# 22   1  350216  NCT04124640    22  34.118563
# 23   1   79817  NCT01208038    23  33.914081
# 24   1  151495  NCT01816295    24  33.445840
#
#                                                 query
# 0   a 19 year old male came to clinic with some se...
# 1   a 19 year old male came to clinic with some se...
# 2   a 19 year old male came to clinic with some se...
# 3   a 19 year old male came to clinic with some se...
# 4   a 19 year old male came to clinic with some se...
# 5   a 19 year old male came to clinic with some se...
# 6   a 19 year old male came to clinic with some se...
# 7   a 19 year old male came to clinic with some se...
# 8   a 19 year old male came to clinic with some se...
# 9   a 19 year old male came to clinic with some se...
# 10  a 19 year old male came to clinic with some se...
# 11  a 19 year old male came to clinic with some se...
# 12  a 19 year old male came to clinic with some se...
# 13  a 19 year old male came to clinic with some se...
# 14  a 19 year old male came to clinic with some se...
# 15  a 19 year old male came to clinic with some se...
# 16  a 19 year old male came to clinic with some se...
# 17  a 19 year old male came to clinic with some se...
# 18  a 19 year old male came to clinic with some se...
# 19  a 19 year old male came to clinic with some se...
# 20  a 19 year old male came to clinic with some se...
# 21  a 19 year old male came to clinic with some se...
# 22  a 19 year old male came to clinic with some se...
# 23  a 19 year old male came to clinic with some se...
# 24  a 19 year old male came to clinic with some se...
#    qid   docid        docno  rank      score  \
# 0    1  132571  NCT01511588     0  42.294260
# 1    1  137074  NCT01689896     1  41.191565
# 2    1  150445  NCT01190904     2  40.756693
# 3    1  156096  NCT02612714     3  40.733572
# 4    1  358654  NCT04630275     4  39.414434
# 5    1   56037  NCT00104572     5  39.367162
# 6    1  128044  NCT01672411     6  38.929173
# 7    1  366889  NCT04036604     7  38.205295
# 8    1   68308  NCT00170339     8  37.978924
# 9    1  217263  NCT02529306     9  37.253048
# 10   1  142769  NCT01425541    10  37.082244
# 11   1   54289  NCT00752869    11  36.794108
# 12   1  323587  NCT04710238    12  36.325593
# 13   1  155799  NCT01270841    13  36.219013
# 14   1  318470  NCT04492553    14  36.218342
# 15   1  142638  NCT01427595    15  35.567633
# 16   1   32236  NCT00472940    16  35.560463
# 17   1   24666  NCT00223860    17  35.364775
# 18   1  297446  NCT03528538    18  35.360187
# 19   1   35620  NCT00392756    19  35.167350
# 20   1  277643  NCT03457740    20  34.959511
# 21   1   32926  NCT00522431    21  34.514782
# 22   1  350216  NCT04124640    22  34.118563
# 23   1   79817  NCT01208038    23  33.914081
# 24   1  151495  NCT01816295    24  33.445840
#
#                                                 query  label
# 0   a 19 year old male came to clinic with some se...    2.0
# 1   a 19 year old male came to clinic with some se...    1.0
# 2   a 19 year old male came to clinic with some se...    0.0
# 3   a 19 year old male came to clinic with some se...    0.0
# 4   a 19 year old male came to clinic with some se...    0.0
# 5   a 19 year old male came to clinic with some se...    1.0
# 6   a 19 year old male came to clinic with some se...    0.0
# 7   a 19 year old male came to clinic with some se...    0.0
# 8   a 19 year old male came to clinic with some se...    0.0
# 9   a 19 year old male came to clinic with some se...    0.0
# 10  a 19 year old male came to clinic with some se...    1.0
# 11  a 19 year old male came to clinic with some se...    1.0
# 12  a 19 year old male came to clinic with some se...    0.0
# 13  a 19 year old male came to clinic with some se...    1.0
# 14  a 19 year old male came to clinic with some se...    0.0
# 15  a 19 year old male came to clinic with some se...    0.0
# 16  a 19 year old male came to clinic with some se...    NaN
# 17  a 19 year old male came to clinic with some se...    0.0
# 18  a 19 year old male came to clinic with some se...    1.0
# 19  a 19 year old male came to clinic with some se...    2.0
# 20  a 19 year old male came to clinic with some se...    NaN
# 21  a 19 year old male came to clinic with some se...    2.0
# 22  a 19 year old male came to clinic with some se...    0.0
# 23  a 19 year old male came to clinic with some se...    0.0
# 24  a 19 year old male came to clinic with some se...    2.0
# {'AP@1000': 0.16395709300388217,
#  'P@5': 0.46399999999999997,
#  'P@10': 0.41200000000000003}

# %% [markdown]
# # Ideas to play around:
#
#
#
# *   Write a script that, for each topic, keeps high representative terms. What is one property of those terms?
# *   Index different document parts and perform retrieval.
# *   Use the PyTerrier operators to create custom pipelines. Try to use different indices for each step and unite the results.
#
# Documentation: https://pyterrier.readthedocs.io/en/latest/index.html
